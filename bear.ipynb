# %%
with open("bear_ai.py") as infile:
    exec(infile.read())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.586496</td>
#       <td>0.228099</td>
#       <td>0.096774</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.404848</td>
#       <td>0.074251</td>
#       <td>0.008065</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.269551</td>
#       <td>0.060396</td>
#       <td>0.024194</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
# ...
