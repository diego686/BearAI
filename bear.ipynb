# %%
with open("bear_ai.py") as infile:
    exec(infile.read())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.528597</td>
#       <td>0.383726</td>
#       <td>0.193548</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.286012</td>
#       <td>0.116805</td>
#       <td>0.056452</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.211966</td>
#       <td>0.070713</td>
#       <td>0.024194</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
# ...
