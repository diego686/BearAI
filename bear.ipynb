# %%
with open("bear_ai.py") as infile:
    exec(infile.read())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.657231</td>
#       <td>0.278236</td>
#       <td>0.112000</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.199041</td>
#       <td>0.056732</td>
#       <td>0.008000</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.145642</td>
#       <td>0.022467</td>
#       <td>0.008000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
# ...

# %%
learn.export()
path=Path()
path.ls(file_exts='.pk1')
# Out:
# (#0) []

# %%
learn_inf = load_learner(path/'export.pkl')
learn_inf.predict('images/grizzly1.jpg')
# Out:
# ('grizzly', tensor(1), tensor([9.4875e-06, 9.9999e-01, 1.3537e-06]))
